# %%
from pathlib import Path
import csv

# %%
csvpath_menu = Path ('menu_data.csv')

# %%
menu = []

with open (csvpath_menu, 'r') as csvfile:
    csvreader_menu = csv.reader(csvfile, delimiter = ',')
    header = next(csvreader_menu)
    print(header)
    for line in csvreader_menu:
        menu.append(line)

print(menu[0])
# Out:
# ['item', 'category', 'description', 'price', 'cost']
# ['edamame', 'appetizers', 'boiled soybeans, maldon sea salt', '4', '1']

# %%
csvpath_sales = Path ('sales_data.csv')

# %%
sales = []

with open (csvpath_sales, 'r') as csvfile:
    csvreader_sales = csv.reader(csvfile, delimiter = ',')
    header = next(csvreader_sales)
    print(header)
    for line in csvreader_sales:
        sales.append(line)

print(sales[0])
# Out:
# ['Line_Item_ID', 'Date', 'Credit_Card_Number', 'Quantity', 'Menu_Item']
# ['1', '01-01-2017', '7437926611570799', '1', 'spicy miso ramen']

# %%
report1 = {}

report1["01-count"] = 0
report1["02-revenues"] = 0
report1["03-cogs"] = 0
report1["04-profit"] = 0

print(report1.keys())
print(report1.values())
# Out:
# dict_keys(['01-count', '02-revenues', '03-cogs', '04-profit'])
# dict_values([0, 0, 0, 0])

# %%
a ={}

for x in range(len(sales)):
    if sales[x][4] not in a:
        a[sales[x][4]] = int(sales[x][3])
    else:
        a[sales[x][4]] += int(sales[x][3])
  
    
sales_item =[]

for s_item, quantity in a.items():
    sales_item.append([s_item, quantity])

print(a)
print(sales_item[0])
# Out:
# {'spicy miso ramen': 9238, 'tori paitan ramen': 9156, 'truffle butter ramen': 8982, 'tonkotsu ramen': 9288, 'vegetarian spicy miso': 9216, 'shio ramen': 9180, 'miso crab ramen': 8890, 'nagomi shoyu': 9132, 'soft-shell miso crab ramen': 9130, 'burnt garlic tonkotsu ramen': 9070, 'vegetarian curry + king trumpet mushroom ramen': 8824}
# ['spicy miso ramen', 9238]

# %%
if "sales_item" in report1.keys():
    print("yes")
else:
    print("no!")
# Out:
# no!

# %%
report ={}

for x in range(len(sales_item)):
    if sales_item[x][0] not in report:
        report[sales_item[x][0]] = {}
        report[sales_item[x][0]]["01-count"] = 0
        report[sales_item[x][0]]["02-revenues"] = 0
        report[sales_item[x][0]]["03-cogs"] = 0
        report[sales_item[x][0]]["04-profit"] = 0
print(report)
# Out:
# {'spicy miso ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'tori paitan ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'truffle butter ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'tonkotsu ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'vegetarian spicy miso': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'shio ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'miso crab ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'nagomi shoyu': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'soft-shell miso crab ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'burnt garlic tonkotsu ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 0, '02-revenues': 0, '03-cogs': 0, '04-profit': 0}}

# %%
items = []
for line in menu:
    item = (line[0])
    price = float(line[3])
    cost = int(line[4])
    profit = price - cost
    
    sales= 0
    
    b = [item, price, cost, profit]
    items.append(b)
    
print(items)
# Out:
# [['edamame', 4.0, 1, 3.0], ['house salad', 4.0, 2, 2.0], ['cucumber sunomono salad', 5.0, 2, 3.0], ['hiyashi wakame seaweed salad', 5.0, 2, 3.0], ['agedashi tofu', 5.0, 2, 3.0], ['hiyayakko tofu', 5.0, 2, 3.0], ['pork floss bao', 4.0, 2, 2.0], ['kakuni bao', 6.0, 3, 3.0], ['edamame fried gyoza (vegan)', 6.0, 3, 3.0], ['fried gyoza', 6.0, 6, 0.0], ['takoyaki', 6.0, 3, 3.0], ['rock shrimp tempura', 6.0, 3, 3.0], ['soft-shell crab tempura', 6.0, 3, 3.0], ['ebi katsu shrimp bao', 6.0, 3, 3.0], ['nagomi shoyu', 11.0, 5, 6.0], ['shio ramen', 11.0, 5, 6.0], ['spicy miso ramen', 12.0, 5, 7.0], ['vegetarian spicy miso', 12.0, 5, 7.0], ['miso crab ramen', 12.0, 6, 6.0], ['soft-shell miso crab ramen', 14.0, 7, 7.0], ['tori paitan ramen', 13.0, 6, 7.0], ['tonkotsu ramen', 13.0, 6, 7.0], ['burnt garlic tonkotsu ramen', 14.0, 6, 8.0], ['vegetarian curry + king trumpet mushroom ramen', 13.0, 7, 6.0], ['truffle butter ramen', 14.0, 7, 7.0], ['green tea', 2.5, 1, 1.5], ['coke', 2.0, 1, 1.0], ['black 
# ...

# %%
print(items[0])
# Out:
# ['edamame', 4.0, 1, 3.0]

# %%
for sales_item, quantity in a.items():
    for item, price, cost, profit in items:
        if sales_item in item:
            report[sales_item]["01-count"] = quantity
            report[sales_item]["02-revenues"] += price * quantity 
            report[sales_item]["03-cogs"] += cost * quantity
            report[sales_item]["04-profit"] += profit * quantity
        else:
            print(f"{sales_item} does not equal {item}! NO MATCH!")
# Out:
# spicy miso ramen does not equal edamame! NO MATCH!
# spicy miso ramen does not equal house salad! NO MATCH!
# spicy miso ramen does not equal cucumber sunomono salad! NO MATCH!
# spicy miso ramen does not equal hiyashi wakame seaweed salad! NO MATCH!
# spicy miso ramen does not equal agedashi tofu! NO MATCH!
# spicy miso ramen does not equal hiyayakko tofu! NO MATCH!
# spicy miso ramen does not equal pork floss bao! NO MATCH!
# spicy miso ramen does not equal kakuni bao! NO MATCH!
# spicy miso ramen does not equal edamame fried gyoza (vegan)! NO MATCH!
# spicy miso ramen does not equal fried gyoza! NO MATCH!
# spicy miso ramen does not equal takoyaki! NO MATCH!
# spicy miso ramen does not equal rock shrimp tempura! NO MATCH!
# spicy miso ramen does not equal soft-shell crab tempura! NO MATCH!
# spicy miso ramen does not equal ebi katsu shrimp bao! NO MATCH!
# spicy miso ramen does not equal nagomi shoyu! NO MATCH!
# spicy miso ramen does not equal shio ramen! NO MATCH!
# ...

# %%
report
# Out:
# {'spicy miso ramen': {'01-count': 9238,
#   '02-revenues': 110856.0,
#   '03-cogs': 46190,
#   '04-profit': 64666.0},
#  'tori paitan ramen': {'01-count': 9156,
#   '02-revenues': 119028.0,
#   '03-cogs': 54936,
#   '04-profit': 64092.0},
#  'truffle butter ramen': {'01-count': 8982,
#   '02-revenues': 125748.0,
#   '03-cogs': 62874,
#   '04-profit': 62874.0},
#  'tonkotsu ramen': {'01-count': 9288,
#   '02-revenues': 250776.0,
#   '03-cogs': 111456,
#   '04-profit': 139320.0},
#  'vegetarian spicy miso': {'01-count': 9216,
#   '02-revenues': 110592.0,
#   '03-cogs': 46080,
#   '04-profit': 64512.0},
#  'shio ramen': {'01-count': 9180,
#   '02-revenues': 100980.0,
#   '03-cogs': 45900,
#   '04-profit': 55080.0},
#  'miso crab ramen': {'01-count': 8890,
#   '02-revenues': 231140.0,
#   '03-cogs': 115570,
#   '04-profit': 115570.0},
#  'nagomi shoyu': {'01-count': 9132,
#   '02-revenues': 100452.0,
#   '03-cogs': 45660,
#   '04-profit': 54792.0},
# ...

# %%
filepath_output = Path ('report_output.txt')
with open (filepath_output, 'a+') as file:
    file.write(f"{report}")
